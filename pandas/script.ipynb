# %%
import pandas as pd

# %%
df1 = pd.read_excel("/home/jkligel/Desktop/test_files/xlsx.xlsx")
df1
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
df1.set_index("First Name")
# Out:
#             0  Last Name  Gender        Country  Age        Date    Id
# First Name
# Dulce       1      Abril  Female  United States   32  15/10/2017  1562
# Mara        2  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# Philip      3       Gent    Male         France   36  21/05/2015  2587
# Kathleen    4     Hanner  Female  United States   25  15/10/2017  3549
# Nereida     5    Magwood  Female  United States   58  16/08/2016  2468
# Gaston      6      Brumm    Male  United States   24  21/05/2015  2554
# Etta        7       Hurn  Female  Great Britain   56  15/10/2017  3598
# Earlean     8     Melgar  Female  United States   27  16/08/2016  2456
# Vincenza    9    Weiland  Female  United States   40  21/05/2015  6548

# %%
df2 = pd.read_csv("/home/jkligel/Desktop/test_files/csv.csv", sep=',')
df2
# Out:
#              User Name First Name Last Name     Display Name   Job Title  \
# 0    chris@contoso.com      Chris     Green      Chris Green  IT Manager
# 1      ben@contoso.com        Ben   Andrews      Ben Andrews  IT Manager
# 2    david@contoso.com      David  Longmuir   David Longmuir  IT Manager
# 3  cynthia@contoso.com    Cynthia     Carey    Cynthia Carey  IT Manager
# 4  melissa@contoso.com    Melissa   MacBeth  Melissa MacBeth  IT Manager
#
#                Department  Office Number  Office Phone  Mobile Phone  \
# 0  Information Technology         123451  123-555-1211  123-555-6641
# 1  Information Technology         123452  123-555-1212  123-555-6642
# 2  Information Technology         123453  123-555-1213  123-555-6643
# 3  Information Technology         123454  123-555-1214  123-555-6644
# 4  Information Technology         123455  123-555-1215  123-555-6645
#
#             Fax          Address     City State or Province  \
# ...

# %%
df2.loc[:5, "Display Name": "Office Phone"]
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-5-7ff882af8e27> in <module>
# ----> 1 df2.loc[:5, "Display Name": "Office Phone"]
#
# NameError: name 'df2' is not defined

# %%
df2.iloc[3, 2:5]
# Out:
# Last Name               Carey
# Display Name    Cynthia Carey
# Job Title          IT Manager
# Name: 3, dtype: object

# %%
df2.drop("User Name", 1)
# Out:
#   First Name Last Name     Display Name   Job Title              Department  \
# 0      Chris     Green      Chris Green  IT Manager  Information Technology
# 1        Ben   Andrews      Ben Andrews  IT Manager  Information Technology
# 2      David  Longmuir   David Longmuir  IT Manager  Information Technology
# 3    Cynthia     Carey    Cynthia Carey  IT Manager  Information Technology
# 4    Melissa   MacBeth  Melissa MacBeth  IT Manager  Information Technology
#
#    Office Number  Office Phone  Mobile Phone           Fax          Address  \
# 0         123451  123-555-1211  123-555-6641  123-555-9821  1 Microsoft way
# 1         123452  123-555-1212  123-555-6642  123-555-9822  1 Microsoft way
# 2         123453  123-555-1213  123-555-6643  123-555-9823  1 Microsoft way
# 3         123454  123-555-1214  123-555-6644  123-555-9824  1 Microsoft way
# 4         123455  123-555-1215  123-555-6645  123-555-9825  1 Microsoft way
#
# ...

# %%
df2.drop(4, 0)
# Out:
#              User Name First Name Last Name    Display Name   Job Title  \
# 0    chris@contoso.com      Chris     Green     Chris Green  IT Manager
# 1      ben@contoso.com        Ben   Andrews     Ben Andrews  IT Manager
# 2    david@contoso.com      David  Longmuir  David Longmuir  IT Manager
# 3  cynthia@contoso.com    Cynthia     Carey   Cynthia Carey  IT Manager
#
#                Department  Office Number  Office Phone  Mobile Phone  \
# 0  Information Technology         123451  123-555-1211  123-555-6641
# 1  Information Technology         123452  123-555-1212  123-555-6642
# 2  Information Technology         123453  123-555-1213  123-555-6643
# 3  Information Technology         123454  123-555-1214  123-555-6644
#
#             Fax          Address     City State or Province  \
# 0  123-555-9821  1 Microsoft way  Redmond                Wa
# 1  123-555-9822  1 Microsoft way  Redmond                Wa
# 2  123-555-9823  1 Microsoft way  Redmond                Wa
# ...

# %%
df2.columns[5]
# Out:
# 'Department'

# %%
df2["Status"] = ['A'] * df2.shape[0]
df2
# Out:
#              User Name First Name Last Name     Display Name   Job Title  \
# 0    chris@contoso.com      Chris     Green      Chris Green  IT Manager
# 1      ben@contoso.com        Ben   Andrews      Ben Andrews  IT Manager
# 2    david@contoso.com      David  Longmuir   David Longmuir  IT Manager
# 3  cynthia@contoso.com    Cynthia     Carey    Cynthia Carey  IT Manager
# 4  melissa@contoso.com    Melissa   MacBeth  Melissa MacBeth  IT Manager
#
#                Department  Office Number  Office Phone  Mobile Phone  \
# 0  Information Technology         123451  123-555-1211  123-555-6641
# 1  Information Technology         123452  123-555-1212  123-555-6642
# 2  Information Technology         123453  123-555-1213  123-555-6643
# 3  Information Technology         123454  123-555-1214  123-555-6644
# 4  Information Technology         123455  123-555-1215  123-555-6645
#
#             Fax          Address     City State or Province  \
# ...

# %%
df2["First Name"] = df2["First Name"] + "June"
df2
# Out:
#              User Name   First Name Last Name     Display Name   Job Title  \
# 0    chris@contoso.com    ChrisJune     Green      Chris Green  IT Manager
# 1      ben@contoso.com      BenJune   Andrews      Ben Andrews  IT Manager
# 2    david@contoso.com    DavidJune  Longmuir   David Longmuir  IT Manager
# 3  cynthia@contoso.com  CynthiaJune     Carey    Cynthia Carey  IT Manager
# 4  melissa@contoso.com  MelissaJune   MacBeth  Melissa MacBeth  IT Manager
#
#                Department  Office Number  Office Phone  Mobile Phone  \
# 0  Information Technology         123451  123-555-1211  123-555-6641
# 1  Information Technology         123452  123-555-1212  123-555-6642
# 2  Information Technology         123453  123-555-1213  123-555-6643
# 3  Information Technology         123454  123-555-1214  123-555-6644
# 4  Information Technology         123455  123-555-1215  123-555-6645
#
#             Fax          Address     City State or Province  \
# ...

# %%
df3 = df2.T
df3
# Out:
#                                          0                       1  \
# User Name                chris@contoso.com         ben@contoso.com
# First Name                       ChrisJune                 BenJune
# Last Name                            Green                 Andrews
# Display Name                   Chris Green             Ben Andrews
# Job Title                       IT Manager              IT Manager
# Department          Information Technology  Information Technology
# Office Number                       123451                  123452
# Office Phone                  123-555-1211            123-555-1212
# Mobile Phone                  123-555-6641            123-555-6642
# Fax                           123-555-9821            123-555-9822
# Address                    1 Microsoft way         1 Microsoft way
# City                               Redmond                 Redmond
# State or Province                       Wa                      Wa
# ...
